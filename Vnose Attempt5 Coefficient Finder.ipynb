# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import numpy as np
from scipy.optimize import curve_fit
import pandas as pd
import matplotlib.pyplot as plt
import math
ncoeffs=3
def langmuir(x, R0 ,power, K, deltaR):
    return R0 - deltaR * (K * x) ** power / (1 + (K * x)**power)


pd.read_csv('D:\RyanB\VirtualNose\TGS2610C\TGS2610C Ethanol.csv', sep=',', names=['C' , 'B'])
R0=12.03
eth=eth_data
x=eth['C']
y=eth['B']
f = lambda x, *c : langmuir(x, 12.0473983, *c)
popt, pcov = curve_fit(f, x, y, [1, 0.011, 9.38])
cocos= [R0, *popt]
print(cocos)
x0=np.logspace(-10,8, 500000, base=10)
plt.plot(x0, [f(x,*popt) for x in x0])

plt.scatter(x,y)
#plt.plot(x0, y0)

plt.yscale("log")
plt.xscale("log")
plt.grid()
# Out:
# [12.03, 0.8163670375481952, 0.007441732997934638, 11.510070962927507]

# %%
x0=np.logspace(2,5, 5000, base=10)
R0=12.03154183
ethanolcurve = lambda x : langmuir(x, R0,1.0, 6.72012700e-03, 1.11639675e+01)
H2curve = lambda x : langmuir(x, R0, 0.8,  1.10513056e-02, 1.14930117e+01)
plt.plot(x0, [ethanolcurve(x) for x in x0])
plt.plot(x0, [H2curve(x) for x in x0])

plt.gca().set_aspect('equal')
plt.ylim(0.1, 100)
plt.xlim(100, 100000)
plt.scatter(eth_data['C'], eth_data['B'])
plt.scatter(H2_data['C'], H2_data['B'])
plt.yscale("log")
plt.xscale("log")
plt.grid()

# %%
# Opens the csv files for the comps and stores in nested dicts by sensor then comp

TGSRaw={"TGS2610C":{"eth": pd.read_csv('D:\RyanB\VirtualNose\TGS2610C\TGS2610C Ethanol.csv', sep=',', names=['C' , 'B']),
                    "hyd": pd.read_csv('D:\RyanB\VirtualNose\TGS2610C\TGS2610C Hydrogen.csv', sep=',', names=['C' , 'B']) ,
                    "met": pd.read_csv('D:\RyanB\VirtualNose\TGS2610C\TGS2610C Methane.csv', sep=',', names=['C' , 'B']),
                    "ibut": pd.read_csv('D:\RyanB\VirtualNose\TGS2610C\TGS2610C IsoButane.csv', sep=',', names=['C' , 'B']),
                    "prop": pd.read_csv('D:\RyanB\VirtualNose\TGS2610C\TGS2610C Propane.csv', sep=',', names=['C' , 'B'])},
        "TGS2610D":{"eth": pd.read_csv('D:\RyanB\VirtualNose\TGS2610D\TGS2610D Ethanol.csv', sep=',', names=['C' , 'B']),
                    "hyd": pd.read_csv('D:\RyanB\VirtualNose\TGS2610D\TGS2610D Hydrogen.csv', sep=',', names=['C' , 'B']),
                    "met": pd.read_csv('D:\RyanB\VirtualNose\TGS2610D\TGS2610D Methane.csv', sep=',', names=['C' , 'B']),
                    "ibut": pd.read_csv('D:\RyanB\VirtualNose\TGS2610D\TGS2610D Iso Butane.csv', sep=',', names=['C' , 'B']),
                    "prop": pd.read_csv('D:\RyanB\VirtualNose\TGS2610D\TGS2610D Propane.csv', sep=',', names=['C' , 'B'])},
        "TGS2611C":{"eth": pd.read_csv('D:\RyanB\VirtualNose\TGS2611C\TGS2611C Ethanol.csv', sep=',', names=['C' , 'B']),
                    "hyd": pd.read_csv('D:\RyanB\VirtualNose\TGS2611C\TGS2611C Hydrogen.csv', sep=',', names=['C' , 'B']),
                    "met": pd.read_csv('D:\RyanB\VirtualNose\TGS2611C\TGS2611C Methane.csv', sep=',', names=['C' , 'B']),
                    "ibut": pd.read_csv('D:\RyanB\VirtualNose\TGS2611C\TGS2611C Iso Butane.csv', sep=',', names=['C' , 'B'])},
        "TGS2611E":{"eth": pd.read_csv('D:\RyanB\VirtualNose\TGS2611E\TGS2611E Ethanol.csv', sep=',', names=['C' , 'B']),
                    "hyd": pd.read_csv('D:\RyanB\VirtualNose\TGS2611E\TGS2611E Hydrogen.csv', sep=',', names=['C' , 'B']),
                    "met": pd.read_csv('D:\RyanB\VirtualNose\TGS2611E\TGS2611E Methane.csv', sep=',', names=['C' , 'B']),
                    "ibut": pd.read_csv('D:\RyanB\VirtualNose\TGS2611E\TGS2611E Isobutane.csv', sep=',', names=['C' , 'B'])},
          "TGS821":{"eth": pd.read_csv('D:\RyanB\VirtualNose\TGS821\TGS821 Ethanol.csv', sep=',', names=['C' , 'B']),
                    "hyd": pd.read_csv('D:\RyanB\VirtualNose\TGS821\TGS821 Hydrogen.csv', sep=',', names=['C' , 'B']),
                    "met": pd.read_csv('D:\RyanB\VirtualNose\TGS821\TGS821 Methane.csv', sep=',', names=['C' , 'B']),
                    "co": pd.read_csv('D:\RyanB\VirtualNose\TGS821\TGS821 CO.csv', sep=',', names=['C' , 'B'])},
         "TGS2602":{"eth": pd.read_csv('D:\RyanB\VirtualNose\TGS2602\TGS2602 Ethanol.csv', sep=',', names=['C' , 'B']),
                    "hyd": pd.read_csv('D:\RyanB\VirtualNose\TGS2602\TGS2602 Hydrogen.csv', sep=',', names=['C' , 'B']),
                    "amm": pd.read_csv('D:\RyanB\VirtualNose\TGS2602\TGS2602 Ammonia.csv', sep=',', names=['C' , 'B']),
                    "h2s": pd.read_csv('D:\RyanB\VirtualNose\TGS2602\TGS2602 H2S.csv', sep=',', names=['C' , 'B']),
                    "tol": pd.read_csv('D:\RyanB\VirtualNose\TGS2602\TGS2602 Toluene.csv', sep=',', names=['C' , 'B'])},
         "TGS2620":{"eth": pd.read_csv('D:\RyanB\VirtualNose\TGS2620\TGS2620 Ethanol.csv', sep=',', names=['C' , 'B']),
                    "hyd": pd.read_csv('D:\RyanB\VirtualNose\TGS2620\TGS2620 Hydrogen.csv', sep=',', names=['C' , 'B']),
                    "met": pd.read_csv('D:\RyanB\VirtualNose\TGS2620\TGS2620 Methane.csv', sep=',', names=['C' , 'B']),
                    "co": pd.read_csv('D:\RyanB\VirtualNose\TGS2620\TGS2620 CO.csv', sep=',', names=['C' , 'B']),
                    "ibut": pd.read_csv('D:\RyanB\VirtualNose\TGS2620\TGS2620 Isobutane.csv', sep=',', names=['C' , 'B'])}}


# creates the lists used for the loops as it is stored in string indices 

jlist=["TGS2610C","TGS2610D", "TGS2611C", "TGS2611E" , "TGS821", "TGS2602", "TGS2620"]
ilist={"TGS2610C":["eth", "hyd", "met", "ibut", "prop"],
       "TGS2610D":["eth", "hyd", "met", "ibut", "prop"], 
       "TGS2611C":["eth", "hyd", "met", "ibut"], 
       "TGS2611E":["eth", "hyd", "met", "ibut"],
       "TGS821":["eth", "hyd", "met", "co"],
       "TGS2602":["eth", "hyd", "amm", "h2s", "tol"],
       "TGS2620":["eth", "hyd", "met","co", "ibut"]} 

# Opens the csv files for the air and stores in a dict
ResistanceLinesData= {"TGS2610Cair": pd.read_csv('D:\RyanB\VirtualNose\TGS2610C\TGS2610C Air.csv', sep=',', names=['C' , 'B']),
                      "TGS2610Dair": pd.read_csv('D:\RyanB\VirtualNose\TGS2610D\TGS2610D Air.csv', sep=',', names=['C' , 'B']),
                      "TGS2611Cair": pd.read_csv('D:\RyanB\VirtualNose\TGS2611C\TGS2611C Air.csv', sep=',', names=['C' , 'B']),
                      "TGS2611Eair": pd.read_csv('D:\RyanB\VirtualNose\TGS2611E\TGS2611E Air.csv', sep=',', names=['C' , 'B']),
                      "TGS821air": pd.read_csv('D:\RyanB\VirtualNose\TGS821\TGS821 Air.csv', sep=',', names=['C' , 'B']),
                      "TGS2602air": pd.read_csv('D:\RyanB\VirtualNose\TGS2602\TGS2602 Air.csv', sep=',', names=['C' , 'B']),
                      "TGS2620air": pd.read_csv('D:\RyanB\VirtualNose\TGS2620\TGS2620 Air.csv', sep=',', names=['C' , 'B'])}

# Finds the atmospheric resistance by taking the value in pure air
R0=np.zeros(7)
for j in range(0,7):
    R0[j]= ResistanceLinesData[jlist[j]+"air"]['B'][0]

# %%
# General Equation used for fitting the curve

def langmuir(x, R ,power, K, deltaR):
    return R - deltaR * (K * x) ** power / (1 + (K * x)**power)
f = lambda x, *c : langmuir(x, R, *c)

# pre allocates the dict for the coefficients
Cos={}
for j in range(0, len(jlist)):
    Cos[jlist[j]]={}
    
# Creates the x range for the curve

x0=np.logspace(-1,5, 5000, base=10)


# loops for each sensor and then each comp in the sensor

for j in range(0, len(jlist)):
    for i in range(0, len(ilist[jlist[j]])):
        
        # pulls raw data to be used for fitting
        meas=TGSRaw[jlist[j]][ilist[jlist[j]][i]]
        x=meas['C']
        y=meas['B']
        
        # Curve fits the data
        f = lambda x, *c : langmuir(x, R0[j], *c)
        popt, pcov = curve_fit(f, x, y, [1, 0.011, R0[j]-0.5])
        
        #saves fitted coefficients to a dict
        cocos= [R0[j], *popt]
        Cos [jlist[j]] [ilist[jlist[j]][i]] =cocos
        
        
        #Plots the curve fit and data points
        curve = lambda x : langmuir(x, cocos[0], cocos[1], cocos[2], cocos[3])
        plt.plot(x0, curve(x0))
        
        plt.scatter(TGSRaw[jlist[j]][ilist[jlist[j]][i]]['C'], TGSRaw[jlist[j]][ilist[jlist[j]][i]]['B'], label=ilist[jlist[j]][i])
   
    # resets plot for each sensor and sets scales
    plt.yscale("log")
    plt.xscale("log")
    plt.legend()
    plt.grid()
    plt.show()
    plt.clf()
# Out:
# C:\Users\RyanB\anaconda3\lib\site-packages\scipy\optimize\minpack.py:829: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# C:\Users\RyanB\anaconda3\lib\site-packages\scipy\optimize\minpack.py:829: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# C:\Users\RyanB\anaconda3\lib\site-packages\scipy\optimize\minpack.py:829: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
